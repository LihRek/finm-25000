# %%
import pandas
import matplotlib.pyplot as plot
import seaborn as sbrn
import numpy as np

# %%
dataset = pandas.read_excel("data.xlsx")

# %%
import pandas as pda

# %%
dataset = pda.read_excel("data.xlsx")

# %%
dataset
# Out:
#    Unnamed: 0                                    ETF Description
# 0         SPY                        Domestic Equity SPDR S&P500
# 1         EFA                        Foreign Equity iShares EAFE
# 2         EEM                           iShares Emerging Markets
# 3         PSP       Private Equity Invesco Global Private Equity
# 4         QAI                     Absolute Return IQ Multi-Strat
# 5         HYG       High Yield iShares High Yield Corporate Bond
# 6         DBC           Invesco DB Commodity Index Tracking Fund
# 7         IYR                 Real Estate iShares US Real Estate
# 8         IEF          Domestic Bonds iShares 7-10 Year Treasury
# 9         BWX  Foreign Bonds SPDR Bloomberg Barclay Internati...
# 10        TIP                Inflation-Indexed iShares TIPS Bond
# 11        SHV                        iShares Short Treasury Bond

# %%
dataset2 = pda.read_excel("data.xlsx", "total returns")

# %%
dataset2
# Out:
#           Date       BWX       DBC       EEM       EFA       HYG       IEF  \
# 0   2009-04-30  0.008993 -0.001000  0.155582  0.115190  0.138461 -0.027452
# 1   2009-05-31  0.053672  0.162663  0.159400  0.131918  0.028554 -0.020773
# 2   2009-06-30  0.005149 -0.026259 -0.022495 -0.014049  0.033517 -0.005571
# 3   2009-07-31  0.031284  0.018568  0.110146  0.100415  0.069191  0.008317
# 4   2009-08-31  0.007628 -0.040365 -0.013136  0.045031 -0.016969  0.007633
# ..         ...       ...       ...       ...       ...       ...       ...
# 153 2022-01-31 -0.026176  0.078922 -0.000205 -0.036350 -0.026549 -0.021130
# 154 2022-02-28 -0.011197  0.064674 -0.043202 -0.034292 -0.008591 -0.003041
# 155 2022-03-31 -0.042240  0.091747 -0.033811  0.005190 -0.012871 -0.040609
# 156 2022-04-30 -0.069696  0.056408 -0.061351 -0.067391 -0.041803 -0.042283
# 157 2022-05-31  0.011250  0.053396 -0.007787  0.026078  0.025120  0.016799
#
#           IYR       PSP       QAI       SHV       SPY       TIP
# ...

# %%
dataset3 = pda.read_excel("data.xlsx", "excess returns")

# %%
dataset3
# Out:
#           Date       BWX       DBC       EEM       EFA       HYG       IEF  \
# 0   2009-04-30  0.008440 -0.001553  0.155029  0.114637  0.137908 -0.028005
# 1   2009-05-31  0.054143  0.163134  0.159871  0.132389  0.029025 -0.020302
# 2   2009-06-30  0.004550 -0.026858 -0.023094 -0.014648  0.032918 -0.006170
# 3   2009-07-31  0.031311  0.018595  0.110173  0.100442  0.069218  0.008345
# 4   2009-08-31  0.007193 -0.040800 -0.013571  0.044596 -0.017404  0.007198
# ..         ...       ...       ...       ...       ...       ...       ...
# 153 2022-01-31 -0.025361  0.079737  0.000610 -0.035535 -0.025734 -0.020315
# 154 2022-02-28 -0.010834  0.065037 -0.042840 -0.033929 -0.008228 -0.002679
# 155 2022-03-31 -0.041877  0.092110 -0.033449  0.005552 -0.012509 -0.040247
# 156 2022-04-30 -0.069406  0.056699 -0.061061 -0.067101 -0.041513 -0.041992
# 157 2022-05-31  0.010315  0.052461 -0.008722  0.025143  0.024185  0.015864
#
#           IYR       PSP       QAI       SPY       TIP
# ...

# %%
import statistics
import math

# %%
BWX= dataset3["BWX"]
DBC= dataset3["DBC"]
EEM= dataset3["EEM"]
EFA= dataset3["EFA"]
HYG= dataset3["HYG"]
IEF= dataset3["IEF"]
IYR= dataset3["IYR"]
PSP= dataset3["PSP"]
QAI= dataset3["QAI"]
SPY= dataset3["SPY"]
TIP= dataset3["TIP"]

# %%
e1=statistics.mean(BWX)*12
e2=statistics.mean(DBC)*12
e3=statistics.mean(EEM)*12
e4=statistics.mean(EFA)*12
e5=statistics.mean(HYG)*12
e6=statistics.mean(IEF)*12
e7=statistics.mean(IYR)*12
e8=statistics.mean(PSP)*12
e9=statistics.mean(QAI)*12
e10=statistics.mean(SPY)*12
e11=statistics.mean(TIP)*12

# %%
v1=statistics.stdev(BWX)*math.sqrt(12)
v2=statistics.stdev(DBC)*math.sqrt(12)
v3=statistics.stdev(EEM)*math.sqrt(12)
v4=statistics.stdev(EFA)*math.sqrt(12)
v5=statistics.stdev(HYG)*math.sqrt(12)
v6=statistics.stdev(IEF)*math.sqrt(12)
v7=statistics.stdev(IYR)*math.sqrt(12)
v8=statistics.stdev(PSP)*math.sqrt(12)
v9=statistics.stdev(QAI)*math.sqrt(12)
v10=statistics.stdev(SPY)*math.sqrt(12)
v11=statistics.stdev(TIP)*math.sqrt(12)

# %%
sr1=e1/v1
sr2=e2/v2
sr3=e3/v3
sr4=e4/v4
sr5=e5/v5
sr6=e6/v6
sr7=e7/v7
sr8=e8/v8
sr9=e9/v9
sr10=e10/v10
sr11=e11/v11

# %%
Q1 = {'Asset Class' : ['BWX', 'DBC', 'EEM', 'EFA', 'HYG','IEF', 'IYR', 'PSP', 'QAI', 'SPY','TIP'],
        'Mean' : [e1, e2, e3, e4, e5, e6, e7, e8, e9, e10, e11],
        'Volatility' : [v1, v2, v3, v4, v5, v6, v7, v8, v9, v10, v11],
      'Sharpe Ratio' : [sr1, sr2, sr3, sr4, sr5, sr6, sr7, sr8, sr9, sr10, sr11]}
df1= pda.DataFrame(Q1)
display(df1)
# Out:
#    Asset Class      Mean  Volatility  Sharpe Ratio
# 0          BWX  0.006390    0.076505      0.083525
# 1          DBC  0.042225    0.181134      0.233116
# 2          EEM  0.073746    0.193170      0.381770
# 3          EFA  0.085370    0.160429      0.532138
# 4          HYG  0.072104    0.085733      0.841033
# 5          IEF  0.023507    0.058628      0.400955
# 6          IYR  0.151888    0.182766      0.831048
# 7          PSP  0.138939    0.217208      0.639657
# 8          QAI  0.020549    0.048389      0.424667
# 9          SPY  0.150734    0.142042      1.061189
# 10         TIP  0.032002    0.045452      0.704078

# %%
M=max(sr1, sr2, sr3, sr4, sr5, sr6, sr7, sr8, sr9, sr10, sr11)
m=min(sr1, sr2, sr3, sr4, sr5, sr6, sr7, sr8, sr9, sr10, sr11)
print(M)
print(m)
# Out:
# 1.061188835567402
# 0.08352526973785378

# %%
#SPY has the largest Sharpe ratio and BWX has the smallest.

# %%
corr_matrix = dataset3.corr()

print("")
print('CORRELATION MATRIX')
display(corr_matrix)
print("")

plot.figure(figsize = (12,8))
sbrn.heatmap(corr_matrix)
plot.show()
# Out:
# CORRELATION MATRIX
#           BWX       DBC       EEM       EFA       HYG       IEF       IYR  \
# BWX  1.000000  0.330982  0.609331  0.559939  0.507747  0.315212  0.388627
# DBC  0.330982  1.000000  0.560808  0.580985  0.465019 -0.413355  0.285696
# EEM  0.609331  0.560808  1.000000  0.851916  0.746547 -0.254467  0.604353
# EFA  0.559939  0.580985  0.851916  1.000000  0.756339 -0.310853  0.671100
# HYG  0.507747  0.465019  0.746547  0.756339  1.000000 -0.157887  0.738514
# IEF  0.315212 -0.413355 -0.254467 -0.310853 -0.157887  1.000000 -0.059095
# IYR  0.388627  0.285696  0.604353  0.671100  0.738514 -0.059095  1.000000
# PSP  0.486088  0.487789  0.797594  0.905540  0.813852 -0.301569  0.737273
# QAI  0.624505  0.535462  0.801072  0.834043  0.750569 -0.085488  0.613673
# SPY  0.401463  0.498145  0.746713  0.871234  0.740805 -0.328127  0.730715
# TIP  0.551875  0.075545  0.233472  0.160054  0.235147  0.664207  0.291943
#
#           PSP       QAI       SPY       TIP
# ...

# %%
#The strongest negative correlation is DBC and IEF at -0.41.
#The strongest positive correlation between distinct assets is PSP and EFA at 0.91
#TIP has performed fairly well with an SR of 0.70 which is superior to IEF and BWX 
#which represent domestic and foreign bonds respectively.
#Given the correlation matrix, TIP has very weak correlation with most asset classes and a low correlation of
#between 0.55-0.66 with the bonds. This is still lower than the correlation between other distinct asssets so
#I agree that HMC is correct in considering TIP a disntinct asset.

# %%
# Compute covariance matrix. 
cov_mat = dataset3.cov() * 12

# To take the inverse, use the linalg sub-module within numpy
invcov_mat = np.linalg.inv(cov_mat)

# Calculate the return vector
mu = np.array([e1, e2, e3, e4, e5, e6, e7, e8, e9, e10, e11])

# Calculate the unit vector, having the same shape as the return vector
unit= np.ones(mu.shape, dtype = 'int')

# Use np.dot to take the dot product of two vectors

scaling = np.dot(np.dot(unit, invcov_mat), mu)

numerator = np.dot(invcov_mat, mu)

tangency_weights = numerator/scaling

    
Q3 = {'Asset Class' : ['BWX', 'DBC', 'EEM', 'EFA', 'HYG','IEF', 'IYR', 'PSP', 'QAI', 'SPY','TIP'],
        'Tangency Weight' : [-0.97307183,  .19166205,  0.12836907, -0.00723276,  1.30831024,  2.15714398,
 -0.3688021,  -0.39909241, -4.33534801,  2.34853023,  0.94953156],}
      
df3= pda.DataFrame(Q3)
display(df3)
# Out:
#    Asset Class  Tangency Weight
# 0          BWX        -0.973072
# 1          DBC         0.191662
# 2          EEM         0.128369
# 3          EFA        -0.007233
# 4          HYG         1.308310
# 5          IEF         2.157144
# 6          IYR        -0.368802
# 7          PSP        -0.399092
# 8          QAI        -4.335348
# 9          SPY         2.348530
# 10         TIP         0.949532

# %%
#I found the expected value using the tangency weights
tmu=np.dot(tangency_weights,mu)

# %%
#This is a component of the variance calculation
mu2 = np.array([e1**2, e2**2, e3**2, e4**2, e5**2, e6**2, e7**2, e8**2, e9**2, e10**2, e11**2])

tmu2=np.dot(tangency_weights,mu2)

#Here I used the formula VAR[X]=E[X^2]-E[X]^2
tvar=abs(tmu2-(tmu**2))
tvol=math.sqrt(tvar)

print(tmu)
print(tvol)
print(tmu/tvol)
# Out:
# 0.33960168224022874
# 0.26476112954007786
# 1.2826719799472

# %%
#The tangency mean is 0.34
#The volatility is 0.26
#The Sharpe Ratio is 1.28

# %%
#Q4, we find the delta star value
mup=0.01

denominator=np.dot(np.dot(np.transpose(mu),invcov_mat),mu)
delta=np.dot(scaling/denominator,mup)
print(delta)
# Out:
# 0.029446261673480648

# %%
opt_weights=np.dot(delta,tangency_weights)
print(opt_weights)
# Out:
# [-0.02865333  0.00564373  0.00377999 -0.00021298  0.03852485  0.06351983
#  -0.01085984 -0.01175178 -0.12765979  0.06915544  0.02796015]

# %%
Q4 = {'Asset Class' : ['BWX', 'DBC', 'EEM', 'EFA', 'HYG','IEF', 'IYR', 'PSP', 'QAI', 'SPY','TIP'],
        'Optimal Weight' : [-0.28653328,  0.05643731,  0.03779989, -0.00212978,  0.38524846,  0.63519826,
 -0.10859843, -0.1175178,  -1.27659792,  0.69155436,  0.27960155],}
      
df4= pda.DataFrame(Q4)
display(df4)
# Out:
#    Asset Class  Optimal Weight
# 0          BWX       -0.286533
# 1          DBC        0.056437
# 2          EEM        0.037800
# 3          EFA       -0.002130
# 4          HYG        0.385248
# 5          IEF        0.635198
# 6          IYR       -0.108598
# 7          PSP       -0.117518
# 8          QAI       -1.276598
# 9          SPY        0.691554
# 10         TIP        0.279602

# %%
#Here we check if the expected return of our portfolio is as we stated
opt_mu=np.dot(opt_weights,mu)
print(opt_mu)
#Close enough
# Out:
# 0.010000000000000002

# %%
opt_var=mup**2/denominator
print(opt_var)
opt_vol=math.sqrt(opt_var)
print (opt_vol)
print(opt_mu/opt_vol)
# Out:
# 2.3690636996292358e-05
# 0.004867302846165662
# 2.0545259491871866

# %%
#Thus we have found that the optimal volatility for a portfolio that returns 10 percent is 4.9 percent volatility.
#The sharpe ratio is an extremely good 2.05
#This portfolio has large long positions in SPY,TIP,IEF and HYG. Meaning a lot of bonds both treasury and corporate.
#The protfolio shorts QAI very heavily and also short BWX and PSP.
#Meaning that it shorts hedge fund, foreign bonds and private equity.
#I don't see a connection with Sharpe ratios only that it plays SPY long with the highest SR and shorts IYR and QAI 
#which also had high SR's

# %%
#Compute equal weights as 1/(number of securities)
eqw_vec = [1/11,1/11,1/11,1/11,1/11,1/11,1/11,1/11,1/11,1/11,1/11]
print(eqw_vec)

#To scale the returns of the portfolio,
mean_rescaler = 0.010/np.dot(np.transpose(mu),eqw_vec)
print(mean_rescaler)

#Rescaled weights are simply equal weights multiplied by the rescaling factor
eqw_vec_re = np.dot(eqw_vec,mean_rescaler)

print(eqw_vec_re)
#to check, rescaled weights produce the target portfolio return:
np.dot(np.transpose(mu),eqw_vec_re)
print(np.dot(np.transpose(mu),eqw_vec_re))
# Out:
# [0.09090909090909091, 0.09090909090909091, 0.09090909090909091, 0.09090909090909091, 0.09090909090909091, 0.09090909090909091, 0.09090909090909091, 0.09090909090909091, 0.09090909090909091, 0.09090909090909091, 0.09090909090909091]
# 0.13793901281192278
# [0.01253991 0.01253991 0.01253991 0.01253991 0.01253991 0.01253991
#  0.01253991 0.01253991 0.01253991 0.01253991 0.01253991]
# 0.01

# %%
#The volatility and sharpe ratio are as follows
eq_mu=0.01
print(eq_mu)

eq_var=np.dot(np.dot(np.transpose(eqw_vec_re),cov_mat),eqw_vec_re)
print(eq_var)
eq_vol=math.sqrt(eq_var)
print(eq_vol)

#Sharpe ratio
print(eq_mu/eq_vol)
# Out:
# 0.01
# 0.00018370946337676139
# 0.01355394641337944
# 0.7377924993217289

# %%
#risk parity

rp_weight_vec=[1/v1,1/v2,1/v3,1/v4,1/v5,1/v6,1/v7,1/v8,1/v9,1/v10,1/v11]
print(rp_weight_vec)

#rescale

mean_rescaler2 = 0.010/np.dot(np.transpose(mu),rp_weight_vec)
print(mean_rescaler)

#Rescaled weights are simply equal weights multiplied by the rescaling factor
rp_vec_re = np.dot(rp_weight_vec,mean_rescaler2)

print(rp_vec_re)
#to check, rescaled weights produce the target portfolio return:
np.dot(np.transpose(mu),rp_vec_re)
print(np.dot(np.transpose(mu),rp_vec_re))

Q9 = {'Asset Class' : ['BWX', 'DBC', 'EEM', 'EFA', 'HYG','IEF', 'IYR', 'PSP', 'QAI', 'SPY','TIP'],
        'Optimal Weight' : [0.0213121, 0.00900152, 0.00844064, 0.01016325, 0.01901807, 0.02781071
 ,0.00892111, 0.00750651, 0.03369,  0.01147882, 0.03587268],}
      
display(pda.DataFrame(Q9))
# Out:
# [13.071086945619525, 5.520787762967549, 5.176795483206499, 6.233302422029516, 11.664115776896544, 17.056798190572465, 5.471470201848045, 4.603874476909501, 20.66573561578705, 7.040161761959947, 22.001341756356513]
# 0.13793901281192278
# [0.0213121  0.00900152 0.00844064 0.01016325 0.01901807 0.02781071
#  0.00892111 0.00750651 0.033695   0.01147882 0.03587268]
# 0.01
#    Asset Class  Optimal Weight
# 0          BWX        0.021312
# 1          DBC        0.009002
# 2          EEM        0.008441
# 3          EFA        0.010163
# 4          HYG        0.019018
# 5          IEF        0.027811
# 6          IYR        0.008921
# 7          PSP        0.007507
# 8          QAI        0.033690
# 9          SPY        0.011479
# 10         TIP        0.035873

# %%
#The volatility and sharpe ratio are as follows
rp_mu=0.01
print(rp_mu)

rp_var=np.dot(np.dot(np.transpose(rp_vec_re),cov_mat),rp_vec_re)
print(eq_var)
rp_vol=math.sqrt(rp_var)
print(rp_vol)

#Sharpe ratio
print(rp_mu/rp_vol)
# Out:
# 0.01
# 0.00018370946337676139
# 0.012711171359355884
# 0.7867095578598771

# %%
#Both of these weightings underpermorm the optimal portfolio significantly
#Both have sharpe ratios under 1, rather similar at 0.74 and 0.79
#The risk parity has less volatility

# %%
#QUESTION 6

dataset3 = dataset3.set_index('Date')
dataset3.index = pda.to_datetime(dataset3.index)
dataset3.head()
# Out:
#                  BWX       DBC       EEM       EFA       HYG       IEF  \
# Date
# 2009-04-30  0.008440 -0.001553  0.155029  0.114637  0.137908 -0.028005
# 2009-05-31  0.054143  0.163134  0.159871  0.132389  0.029025 -0.020302
# 2009-06-30  0.004550 -0.026858 -0.023094 -0.014648  0.032918 -0.006170
# 2009-07-31  0.031311  0.018595  0.110173  0.100442  0.069218  0.008345
# 2009-08-31  0.007193 -0.040800 -0.013571  0.044596 -0.017404  0.007198
#
#                  IYR       PSP       QAI       SPY       TIP
# Date
# 2009-04-30  0.295598  0.229649  0.022329  0.098794 -0.018504
# 2009-05-31  0.023198  0.054364  0.028336  0.058924  0.020438
# 2009-06-30 -0.025462  0.044850 -0.004035 -0.001254  0.001382
# 2009-07-31  0.105826  0.143274  0.015353  0.074633  0.000906
# 2009-08-31  0.131503  0.032977 -0.004586  0.036505  0.007979

# %%
insample_data = dataset3.loc[:"2020"]
print("Part A Data")
display(insample_data)


insample_data1 = dataset3.loc[:'2021']

print("Part B Data")
display(insample_data1)

outsample_data = dataset3.loc["2022"]

print("Part C Data")
display(outsample_data)
# Out:
# Part A Data
#                  BWX       DBC       EEM       EFA       HYG       IEF  \
# Date
# 2009-04-30  0.008440 -0.001553  0.155029  0.114637  0.137908 -0.028005
# 2009-05-31  0.054143  0.163134  0.159871  0.132389  0.029025 -0.020302
# 2009-06-30  0.004550 -0.026858 -0.023094 -0.014648  0.032918 -0.006170
# 2009-07-31  0.031311  0.018595  0.110173  0.100442  0.069218  0.008345
# 2009-08-31  0.007193 -0.040800 -0.013571  0.044596 -0.017404  0.007198
# ...              ...       ...       ...       ...       ...       ...
# 2020-08-31  0.004145  0.046404  0.028911  0.047256 -0.000187 -0.009662
# 2020-09-30 -0.012164 -0.035396 -0.010049 -0.020414 -0.009262  0.003332
# 2020-10-31  0.010069 -0.031511  0.013945 -0.035624  0.003916 -0.013925
# 2020-11-30  0.020691  0.102184  0.090120  0.142902  0.033720  0.003591
# 2020-12-31  0.023918  0.054320  0.071096  0.049955  0.019380 -0.002583
#
#                  IYR       PSP       QAI       SPY       TIP
# Date
# ...

# %%
#Using the same approch from Q4 we do this with data A:
cols=['BWX', 'DBC', 'EEM', 'EFA', 'HYG','IEF', 'IYR', 'PSP', 'QAI', 'SPY','TIP']
mu6a=np.dot(12,np.array(insample_data[cols].mean()))
print(mu6a)
# Out:
# [ 0.02626422 -0.01329334  0.09766578  0.09495408  0.08295793  0.03664414
#   0.15224937  0.15987845  0.02857646  0.15714301  0.03565006]

# %%
vol6a=np.dot(math.sqrt(12),np.array(insample_data1[cols].std()))
print(vol6a)
# Out:
# [0.07373315 0.1790072  0.19451558 0.16073692 0.08520802 0.05653255
#  0.18129611 0.21413999 0.04769314 0.13968741 0.04476654]

# %%
###### Compute covariance matrix. 
cov_mat6a = insample_data.cov() *12


# To take the inverse, use the linalg sub-module within numpy
invcov_mat6a = np.linalg.inv(cov_mat6a)

# Calculate the unit vector, having the same shape as the return vector
unit6a= np.ones(mu6a.shape, dtype = 'int')



# Use np.dot to take the dot product of two vectors

scaling6a = np.dot(np.dot(unit6a, invcov_mat6a), mu6a)

numerator6a = np.dot(invcov_mat6a, mu6a)

tangency_weights6a = numerator6a/scaling6a

#Q6a, we find the delta star value
mup6a=0.01

denominator6a=np.dot(np.dot(np.transpose(mu6a),invcov_mat6a),mu6a)
delta6a=np.dot(scaling6a/denominator6a,mup6a)
opt_weights6a=np.dot(delta6a,tangency_weights6a)
print(opt_weights6a)
Q6 = {'Asset Class' : ['BWX', 'DBC', 'EEM', 'EFA', 'HYG','IEF', 'IYR', 'PSP', 'QAI', 'SPY','TIP'],
        'Optimal Weights' : [-0.03251228, -0.05902893,  0.02261935, -0.06349035,  0.38451792,  0.70399312,
 -0.17417582, -0.02069998, -0.9981324,   0.65452248,  0.04740016],}
      
df6= pda.DataFrame(Q6)
display(df6)
# Out:
# [-0.00325123 -0.00590289  0.00226193 -0.00634904  0.03845179  0.07039931
#  -0.01741758 -0.00207    -0.09981324  0.06545225  0.00474002]
#    Asset Class  Optimal Weights
# 0          BWX        -0.032512
# 1          DBC        -0.059029
# 2          EEM         0.022619
# 3          EFA        -0.063490
# 4          HYG         0.384518
# 5          IEF         0.703993
# 6          IYR        -0.174176
# 7          PSP        -0.020700
# 8          QAI        -0.998132
# 9          SPY         0.654522
# 10         TIP         0.047400

# %%
#Using the means from 2021, 6b)
mu6b=np.dot(opt_weights6a,np.dot(12,np.array(insample_data1[cols].mean())))
print(mu6b)
opt_var6b=mup6a**2/denominator6a
opt_vol6b=math.sqrt(opt_var6b)
opt_sr6b=mu6b/opt_vol6b
print(opt_sr6b)

#Now for part C


mu6c=np.dot(opt_weights6a,np.dot(5,np.array(outsample_data[cols].mean())))
print(mu6c)
opt_var6c=mup6a**2/denominator6a
opt_vol6c=math.sqrt(opt_var6c)
opt_sr6c=mu6c/opt_vol6c
print(opt_sr6c)
# Out:
# 0.009807832380615448
# 2.245851991718485
# -0.008978925984782234
# -2.0560443963409836

# %%
#6b) The mean return is 0.098 and the SR is 2.25
#6c) The mean return is -0.090 and the SR is -2.06
#Applying the 2020 weights to the data up to 2021 yields a higher sharpe ratio.
#Applying the weights to data from 2022 yields negative values as we entered a bear market this year
